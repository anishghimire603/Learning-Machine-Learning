# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("RGB_Matte.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (480, 640, 3)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x1A46A2F6A48>

# %%
red = arr[50:300, :200]

# %%
plt.imshow(red)
