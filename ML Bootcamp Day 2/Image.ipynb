# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("anish-ml-image.png")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (747, 567, 4)

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=567x747 at 0x2968A9BB708>

# %%
cut = arr[1:5, :5]

# %%
plt.imshow(cut)

# %%
plt.imshow(arr)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]] =0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray, cmap="gray")
